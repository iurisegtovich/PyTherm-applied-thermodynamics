# %% [markdown]
# # Trabalho de Termodinâmica Aplicada:
# ### Cálculos de propriedades termodinâmicas e de equilíbrio de fases utilizando equações de estado e modelos de G de excesso

# %% [markdown]
# #### Este trabalho é dividido em duas partes principais. Na primeira parte são feitos cálculos para os componentes puros ÁGUA e ETANOL, considerando a Equação de Estado SRK. Na segunda parte os cálculos são feitos para a mistura destes compostos, utilizando o modelo NRTL de G de excesso .
#
# #### *PARTE 1*

# %% [markdown]
# ### *A) Cálculo da pressão de saturação pela Equação de Estado Soave-Redlich-Kwong (SRK)*
#
# Primeira Etapa: Importação das bibliotecas

# %%
import numpy as np

# %%
from scipy import optimize as opt

# %% [markdown]
# As propriedades conhecidas das substâncias são as propriedades críticas (Tc e Pc) e o fator acêntrico (representado por w).
#
# Considere a Equação de Estado de SRK, conforme definição abaixo:
#
# $P=\frac{RT}{\bar{V}-b}-\frac{a(T)}{{\bar{V}}({\bar{V}+b})}$
#
# Onde, os parâmetros "a" e "b" podem ser calculados por:
#
# $a(T)=\frac {{0.42748} {alpha} {R^2} {Tc^2}}{Pc} $
#
# $b=\frac{{0.08664} {R}{Tc}}{{Pc}}$
#
# O cálculo de alpha depende do fator acêntrico, conforme pode ser visto a paritr das duas equações a seguir:
#
# $m={(0.48+1.574{w}-0.176{w^2})}$
#
# $alpha={[1+{m}{(1-Tr^{1/2})}]^2}$
#
# Onde
#
# $Tr=\frac {T}{Tc}$

# %%
# Dados iniciais - Propriedades Críticas da água e etanol
# Temperatura - Kelvin
# Pressão - Pa

# Constante de gás
R = 8.3144598 #J.mol^−1.K^−1

#Tc (K)
#Pc (Pa)

#Agua - Propriedades das substâncias puras

Tc=647.1
Pc = 220.55*(10**5)
w = 0.345

#definindo constante b
b=0.08664*(R*Tc)/Pc

# %% [markdown]
# Uma vez definidas as constantes a serem trabalhadas, a seguir será realizado o cálculo da Pressão de Saturação da substância pura.
# Inicialmente, para dado P e T, estamos interessado em calcular os volumes das fases líquida e gasosa. A equação de SRK é uma equação de terceira ordem. Consequentemente, a equação possui três raízes. A menor raiz representa a fase liquida e a maior representa a fase gasosa. A raiz intermediária é desprezada.
# Para SRK, a solução é feita a partir da resolução do polinômio de terceira ordem abaixo:
#
# ${P}{{\bar{V}}^3}-{(RT)}{{\bar{V}}^2}+{(a-Pb^2-RTb)}{\bar{V}}-ab=0$
#
# Realizando o cálculo para uma pressão e temperatura definidas

# %%
#Cálculo dos volumes para as condições abaixo
T = 323 #K
P = 100000 #Pa

T=323
Tr=T/Tc
m=(0.48+1.574*w-0.176*w**2)
alpha=(1+(m*(1-Tr**0.5)))**2
a=0.42748*(alpha*R**2*Tc**2)/Pc

# %% [markdown]
# Primeiro, são definidas as constantes do polinômio

# %%
#declaração dos coeficientes da Raiz da EOS de SRK
c3 = P #coeficiente de v^3  
c2 = -(R*T) #coeficiente de v^2
c1 = (a-P*b**2-R*T*b)  #coeficiente de v^1  
c0 = -a*b  #coeficiente de v^0

# %% [markdown]
# Os volumes são obtidos a aprtir da definição das raízes da equação

# %%
#Para achar as raízes do polinômio, utiliza-se a biblioteca do numpy importada anteriormente
v=np.roots([c3,c2,c1,c0])
print(v)
# Out:
# [  2.65231353e-02   3.08281187e-04   2.42886770e-05]

# %% [markdown]
# Conforme dito anteriormente, colocando em ordem crescente as raízes calculadas, chega-se ao volume da fase líquida e o volume da fase gasosa

# %%
[v_Liq, v_intermediate, v_Vap] = np.sort(v)
print( "T",T,"K","","P",P,"Pa","","V_liq",v_Liq,"V_vap", v_Vap )
# Out:
# T 323 K  P 100000 Pa  V_liq 2.42886769674e-05 V_vap 0.02652313529

# %% [markdown]
# ### Energia livre de Gibbs Residual
#
# A Energia Livre de Gibbs Residual pode ser expressa da seguinte forma:
#
# $${\bar{G}^{Res}}={{(RT)} {[Z-1-ln(Z-Beta)-qI]}}$$
#
# Onde:
#
# $Beta=\frac{bP} {RT}$
#
# $Z=\frac{PV}{RT}$  O cálculo de Z será realizado considerando os volumes do líquido ou de vapor, a depender da fase estudada
#
# $q=\frac{alpha}{bRT}$
#
# $I={ln(\frac{Z+Beta}{Z})}$
#
# > Smith, van Ness, Abbott, 2005, 7th-pt-BR, Ch. (6.2, 6.3)

# %%
Z_liq=P*v_Liq/(R*T)
Z_vap=P*v_Vap/(R*T)
beta=b*P/(R*T)
q=a/(b*R*T)
I_liq=np.log((Z_liq+beta)/Z_liq)
I_vap=np.log((Z_vap+beta)/Z_vap)
G_residual_liq=R*T*(Z_liq-1-np.log(Z_liq-beta)-q*I_liq)
G_residual_vap=R*T*(Z_vap-1-np.log(Z_vap-beta)-q*I_vap)

print(T, "K", P, "Pa", G_residual_liq, G_residual_vap)
# Out:
# 323 K 100000 Pa -6210.95866061 -33.0643042073

# %% [markdown]
# Obs: A menor energia de Gibbs residual representa a fase mais estável na temperatura e pressão calculada

# %% [markdown]
# ## Cálculo da Pressão de Saturação
#
# Agora, a pressão de saturação é a pressão $ P $ que faz com que a diferença na energia residual de Gibbs entre o líquido de ensaio e a fase de vapor seja igual a zero a uma determinada temperatura. Não podemos explicitar $P$ como uma função da diferença na energia residual de Gibbs, então definimos uma função $ Residuo=abs(G_residual_liq - G_residual_vap) $ de $ P $
# e vamos resolvê-lo numericamente, ou seja, tentar vários valores de $ P $ de acordo com uma metodologia de atualização e critérios de convergência.
#
# Para automatizar essa tarefa, implementamos uma função chamada ** `def Psat (T,iguessP):` **, que calcula as raízes do volume, como antes, e avalia a diferença entre a energia residual de Gibbs em cada um desses estados.

# %%
def P_sat(T,iguess_P):
    
    
#funções de T
#Definição das condições de contorno para o cálculo da Pressão de Saturação
    
    Tr=T/Tc
    m=(0.48+1.574*w-0.176*w**2)
    alpha=(1+(m*(1-Tr**0.5)))**2
    a=0.42748*(alpha*R**2*Tc**2)/Pc
 

    Residuo=1
    TOL=1e-9
    MAX=1000
    i=0
    P=iguess_P
 

############################# funções de P #declaração dos coeficientes da Raiz da EOS de SRK

    while(Residuo>TOL and i<MAX):#Ges dependem de V q depende de P
 
        c3 = P #coeficiente de v^3  
        c2 = -(R*T) #coeficiente de v^2
        c1 = (a-P*b**2-R*T*b)  #coeficiente de v^1  
        c0 = -a*b  #coeficiente de v^0
        v=np.roots([c3,c2,c1,c0])#Para achar as raízes do polinômio, utiliza-se a biblioteca do numpy importada anteriormente
        [v_Liq, v_intermediate, v_Vap] = np.sort(v)
                        
        Z_liq=P*v_Liq/(R*T)
        Z_vap=P*v_Vap/(R*T)
        beta=b*P/(R*T)
        q=a/(b*R*T)
        I_liq=np.log((Z_liq+beta)/Z_liq)
        I_vap=np.log((Z_vap+beta)/Z_vap)
        G_residual_liq=R*T*(Z_liq-1-np.log(Z_liq-beta)-q*I_liq)
        G_residual_vap=R*T*(Z_vap-1-np.log(Z_vap-beta)-q*I_vap)
        Residuo=abs(G_residual_liq - G_residual_vap)
        phi_L=np.exp(G_residual_liq/(R*T))
        phi_V=np.exp(G_residual_vap/(R*T))
        P=P*(phi_L/phi_V)
        i=i+1      

    
    return P

Psat=P_sat(356.2,101325)   
print ("Psat=",Psat)
# Out:
# Psat= 47201.2370933

# %% [markdown]
# Para montagem do gráfico são selecionados 100 pontos de temperatura, começando e 100 K e indo até a temperatura crítica da substância. Para temperatura é calculada a pressão de saturação de referência.
#
# Particularmente, nesta etapa, observou-se uma mensagem ao final. O que acontece é que em T = 636, já está em 98,3% de Tc, a pressão da complexo. Iisso é uma propagação de cálculos desde o calculo de V (phi deu complexo, Gres deu complexo, V deu comlexo). O volume, então, deu complexo por 1 de dois motivos:
#
# 1. Não há mais raiz real -- o ponto crítico previsto pela equação de estado está ligeiramente abaixo dos valores esperados (Tc, Pc, usados para parametrizar a e b)
# 2. houve erro numérico no solver roots (note que em 636 K temos uma parte complexa de valor 4e-8, que é quase zero)
# 3. ou uma combinação dos dois fenomenos: aproximação numerica em 636 e 641; subprevisão do ponto crítico em 647 (teoricamente em cima do ponto critico ainda deveriamos conseguir convergir)
#
#     # Isso é normal acontecer em uma implementação numérica
#
# A princípio, os métodos numéricos que estão sendo empregados já desprezam a parte complexa.
# Onde foi calculado Psat = 22054853.2794+5.44533447393j, o programa já está plotando como 22054853.2794

# %%
guessP=100
Taxis=np.linspace(100,Tc,100) 
Paxis=np.zeros(100) 
Paxis[0]=P_sat(Taxis[0],guessP)
for i in range(1,100): #
    Paxis[i]=P_sat(Taxis[i],Paxis[i-1])
    #print(Paxis[i])
# Out:
# C:\Users\cls4\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: ComplexWarning: Casting complex values to real discards the imaginary part

# %% [markdown]
# ### *Calculo da Pressão de Saturação utilizando a Equação de Antoine*
#
# As informações para a utilização da Equação de Antoine foram obtidas em (http://webbook.nist.gov/cgi/cbook.cgi?ID=C7732185&Mask=4&Type=ANTOINE&Plot=on)
#
#
#
# A Equação é a seguinte:
#
# log(P) = A − (B / (T + C))
#
# onde P = pressão de vapor (bar)e T = temperatura (K)
#
#
# A, B e C são parâmetros determinados a partir de dados experimentais, e são válidos para faixas de temperatura definidas (pressão em bar, temperatura em K).
#
# |       Etanol        |    A     |     B     |     C     |
# |---------------------|----------|-----------|-----------|
# |  364.8 a 513.91 K   | 4.92531  | 1432.526  |  -61.819  |
# |  292.77 a 366.63 K  | 5.24677  | 1598.673  |  -46.424  |
# |  273 a 351.70 K     | 5.37229  | 1670.409  |  -40.191  |
# |    **Água**         |          |           |           |
# |  379 a 573 K        | 3.55959  | 643.748   | -198.043  |
# |  344 a 373 K        | 5.08354  | 1663.125  |  -45.622  |
# |  334 a 363 K        | 5.07680  | 1659.793  |  -45.854  |
# |  304 a 333 K        | 5.20389  | 1733.926  |  -39.485  |
# |  273 a 303 K        | 5.40221  | 1838.675  |  -31.737  |
#
#
# Na literatura estão disponíveis algumas variações na forma da Equação de Antoine, utilizando ln ao inves de log, ou temperatura em oC e pressão em kPa, e deve-se tomar cuidado ao utilizar os parâmetros acima nas unidades corretas.

# %%
def Pantoine(T): 

    if T<(273): 
        return 0
    
    elif T<(303): 
        A = 5.40221
        B = 1838.675
        C = -31.737
        
    elif T<(333):
        A = 5.20389
        B = 1733.926
        C = -39.485
        
    elif T<(363):
        A = 5.07680   
        B = 1659.793
        C = -45.854
        
    else: 
        return 0
    
    return 10**(A - B/(C+T))*100000 

Psat_ant=Pantoine(373.15)  
print("Psat_ant",Psat_ant)
# Out:
# Psat_ant 0

# %% [markdown]
# ### *Aquisição de dados experimentais*

# %%
# obtenção dos dados experimentais de pressão de vapor de água
table = np.loadtxt('Dados de Psat - agua.txt', dtype='float', comments='#', delimiter=None, converters=None, skiprows=0, usecols=None, unpack=False, ndmin=0)
T_exp = table[:,0]
P_exp = table[:,1]

# %% [markdown]
# ### Plotar gráfico (SRK, Antoine, Dados experimentais)

# %%
import matplotlib.pyplot as plt

#gerando matriz de dados com Pressão calculada por Antoine

Pantoineaxis = np.zeros(100) 
Pantoineaxis = [ Pantoine(Taxis[i]) for i in range(100) ] 

plt.figure(1)

plt.xlim([100,1.1*Tc]) #<- Definindo limites diferente para cada plot
plt.ylim([100,10*Pc])

plt.scatter(T_exp,P_exp)
plt.semilogy(Taxis,Paxis)
plt.semilogy(Taxis,Pantoineaxis)

plt.scatter(Tc,Pc,marker="*") #<- Ponto crítico foi marcado com um asterisco para ver se o gráfico chegou até lá com sucesso


plt.figure(2)

plt.xlim([100,1.1*Tc]) #<- Definindo limites diferente para cada plot
plt.ylim([100,1.1*Pc])

plt.scatter(T_exp,P_exp)
plt.plot(Taxis,Paxis)
plt.plot(Taxis,Pantoineaxis)

plt.scatter(Tc,Pc,marker="*") #<- Ponto crítico foi marcado com um asterisco para ver se o gráfico chegou até lá com sucesso
plt.show()

# %% [markdown]
# ## Cálculo de Entalpia, Entropia e Volume Molar
#
# Uma vez calculadas as condições de saturação (temperatura e pressão), o próximo objetivo do trabalho foi calcular a Entalpia e Entropia para o componente puro selecionado.
#
# Para a equação de SRK, as seguintes equações foram encontradas para o cálculo da entalpia e entropia:
#
# $\frac{H^{res}}{RT}= {(Z-1)}+ [\frac{dlnalpha(Tr)}{dlnTr}-1]{q}{I}$
#
# Onde:
#
#
# $Z=\frac{PV}{RT}$  O cálculo de Z será realizado considerando os volumes do líquido ou de vapor, a depender da fase estudada
#
# $q=\frac{alpha}{bRT}$
#
# $I={ln(\frac{Z+Beta}{Z})}$
#
# > Smith, van Ness, Abbott, 2005, 7th-pt-BR, Capítulo 6
#
# Para SRK:
#
# $\frac{dlnalpha(Tr)}{dlnTr}=-{m}(\frac{Tr}{alpha})^{0.5}$
#
# A partir do valor calculado para G residual das fases líquida e vapor e dos valores de entalpia, a entropia é calculada conforme a relação abaixo:
#
# ${S^{res}}= \frac{Hre-Gres}{T}$

# %%
def HSFUNCIONALIZADO(T,P):
    
    Tr=T/Tc
    m=(0.48+1.574*w-0.176*w**2)
    alpha=(1+(m*(1-Tr**0.5)))**2
    a=0.42748*(alpha*R**2*Tc**2)/Pc
    
    #Calculando os volumes
    #declaração dos coeficientes da Raiz da EOS de SRK
    c3 = P  #coeficiente de v^3  
    c2 = -(R*T) #coeficiente de v^2
    c1 = (a-P*b**2-R*T*b)  #coeficiente de v^1  
    c0 = -a*b  #coeficiente de v^0
    v=np.roots([c3,c2,c1,c0])#Para achar as raízes do polinômio, utiliza-se a biblioteca do numpy importada anteriormente
    [v_Liq, v_intermediate, v_Vap] = np.sort(v)
    #print( "VL",v_Liq,"VV", v_Vap )

    Z_liq=P*v_Liq/(R*T)
    
    Z_vap=P*v_Vap/(R*T)
    
    
    
    ######ENTALPIA
    beta=b*P/(R*T)
    q=a/(b*R*T)
    I_liq=np.log((Z_liq+beta)/Z_liq)
    I_vap=np.log((Z_vap+beta)/Z_vap)
    der_Tr=-m*(Tr/alpha)**0.5
    
    
    Hres_liq=R*T*(Z_liq-1+(der_Tr-1)*q*I_liq)
    Hres_vap=R*T*((Z_vap-1)+(der_Tr-1)*q*I_vap)
    Res_H=abs(Hres_liq - Hres_vap)
    
    desvio_dH = 100*(Res_H-40700)/40700
    
    print("DESVIO dH calc Dh exp: ",desvio_dH,"%, aceitável")
    print("Hres_liq",Hres_liq)
    print("Hres_vap",Hres_vap)
    print("Res_H",Res_H, "J/mol",Res_H/18,"kJ/kg")
    
    
    
    ######ENTROPIA
    
    Gres_liq=R*T*(Z_liq-1-np.log(Z_liq-beta)-q*I_liq)
    Gres_vap=R*T*(Z_vap-1-np.log(Z_vap-beta)-q*I_vap)
    Res_G=abs(Gres_liq - Gres_vap)
    print("Res_G",Res_G)
    
    Sres_liq=(Hres_liq-Gres_liq)/T
    Sres_vap=(Hres_vap-Gres_vap)/T
    Res_S=abs(Sres_liq - Sres_vap)
    
    print("Sres_liq",Sres_liq)
    print("Sres_vap",Sres_vap)
    print("Res_S",Res_S, "J/mol",Res_S/18,"kJ/kg")
    
    #LOGO PODEMOS FAZER A SEGUINTE PROVA REAL: DELTAH-TDELTAS=0??
    Prova_real=Res_H-T*Res_S
    print("PROVA REAL: DELTAH-TDELTAS=0??",Prova_real)
    
    return Hres_liq, Hres_vap, Sres_liq, Sres_vap

#Teste no pto de ebulição atmosferica da agua

teste = HSFUNCIONALIZADO(373.15,P_sat(373.15,1e5)) #pto de ebulição atmosferica aproximado
# Out:
# DESVIO dH calc Dh exp:  5.66990600925 %, aceitável
# Hres_liq -43073.411979
# Hres_vap -65.7602332265
# Res_H 43007.6517458 J/mol 2389.31398588 kJ/kg
# Res_G 4.91340301778e-12
# Sres_liq -115.367950997
# Sres_vap -0.112285056792
# Res_S 115.255665941 J/mol 6.40309255226 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12

# %%
#Agrupando os resultados de entalpia e entropia

H_axis_l = np.zeros(100)
H_axis_v = np.zeros(100)
S_axis_l = np.zeros(100)
S_axis_v = np.zeros(100)

for i in range (0,100):
    H_axis_l[i], H_axis_v[i],S_axis_l[i], S_axis_v[i]=(HSFUNCIONALIZADO(Taxis[i],Paxis[i]))
    

plt.figure(1)
plt.semilogy(H_axis_l,Paxis)
plt.semilogy(H_axis_v,Paxis)

plt.figure(2)
plt.plot(S_axis_l,Taxis)
plt.plot(S_axis_v,Taxis)

plt.show()
# Out:
# DESVIO dH calc Dh exp:  45.0120174015 %, aceitável
# Hres_liq -59019.8910824
# Hres_vap 0.0
# Res_H 59019.8910824 J/mol 3278.88283791 kJ/kg
# Res_G 5.90777901266e-12
# Sres_liq -590.198910824
# Sres_vap 0.0
# Res_S 590.198910824 J/mol 32.7888283791 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  43.987683719 %, aceitável
# Hres_liq -58602.9872736
# Hres_vap 0.0
# Res_H 58602.9872736 J/mol 3255.7215152 kJ/kg
# Res_G 0.0
# Sres_liq -555.340308802
# Sres_vap 0.0
# Res_S 555.340308802 J/mol 30.8522393779 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  42.986272384 %, aceitável
# Hres_liq -58195.4128603
# Hres_vap 0.0
# Res_H 58195.4128603 J/mol 3233.07849224 kJ/kg
# Res_G 6.5607377799e-12
# Sres_liq -524.03502512
# Sres_vap 0.0
# Res_S 524.03502512 J/mol 29.1130569511 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  42.0059165898 %, aceitável
# Hres_liq -57796.4080521
# Hres_vap 0.0
# Res_H 57796.4080521 J/mol 3210.91155845 kJ/kg
# Res_G 6.88721716352e-12
# Sres_liq -495.771221366
# Sres_vap 0.0
# Res_S 495.771221366 J/mol 27.5428456315 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  41.0449645732 %, aceitável
# Hres_liq -57405.3005813
# Hres_vap 0.0
# Res_H 57405.3005813 J/mol 3189.18336563 kJ/kg
# Res_G 0.0
# Sres_liq -470.130435587
# Sres_vap 0.0
# Res_S 470.130435587 J/mol 26.1183575326 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  40.101945652 %, aceitável
# Hres_liq -57021.4918803
# Hres_vap -1.17815248918e-12
# Res_H 57021.4918803 J/mol 3167.86066002 kJ/kg
# Res_G 6.27845769604e-28
# Sres_liq -446.767258609
# Sres_vap -9.23090470728e-15
# Res_S 446.767258609 J/mol 24.8204032561 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  39.1755428159 %, aceitável
# Hres_liq -56644.4459261
# Hres_vap -2.76040946832e-11
# Res_H 56644.4459261 J/mol 3146.91366256 kJ/kg
# Res_G 6.12641054319e-12
# Sres_liq -425.394091202
# Sres_vap -1.02217457386e-13
# Res_S 425.394091202 J/mol 23.6330050668 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  38.2645703857 %, aceitável
# Hres_liq -56273.680147
# Hres_vap -1.56306358984e-10
# Res_H 56273.680147 J/mol 3126.31556372 kJ/kg
# Res_G 5.28758691092e-12
# Sres_liq -405.769560482
# Sres_vap -6.33496553288e-13
# Res_S 405.769560482 J/mol 22.5427533601 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  37.3679556377 %, aceitável
# Hres_liq -55908.7579445
# Hres_vap -9.42148580016e-10
# Res_H 55908.7579445 J/mol 3106.04210803 kJ/kg
# Res_G 3.37487475915e-12
# Sres_liq -387.689610873
# Sres_vap -3.72083491447e-12
# Res_S 387.689610873 J/mol 21.5383117152 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  36.484723564 %, aceitável
# Hres_liq -55549.2824906
# Hres_vap -4.96999736761e-09
# Res_H 55549.2824906 J/mol 3086.07124948 kJ/kg
# Res_G 7.43895241877e-12
# Sres_liq -370.980576405
# Sres_vap -1.90223804547e-11
# Res_S 370.980576405 J/mol 20.6100320225 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  35.6139841359 %, aceitável
# Hres_liq -55194.8915433
# Hres_vap -2.31264654294e-08
# Res_H 55194.8915433 J/mol 3066.38286352 kJ/kg
# Res_G 4.99893025419e-12
# Sres_liq -355.49373904
# Sres_vap -8.56461165068e-11
# Res_S 355.49373904 J/mol 19.7496521689 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  34.7549215823 %, aceitável
# Hres_liq -54845.2530841
# Hres_vap -9.5767721863e-08
# Res_H 54845.253084 J/mol 3046.95850467 kJ/kg
# Res_G 2.73116180479e-12
# Sres_liq -341.101014274
# Sres_vap -3.4354362127e-10
# Res_S 341.101014274 J/mol 18.9500563486 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 1.45519152284e-11
# DESVIO dH calc Dh exp:  33.906785305 %, aceitável
# Hres_liq -54500.0616195
# Hres_vap -3.57306892611e-07
# Res_H 54500.0616191 J/mol 3027.78120106 kJ/kg
# Res_G 4.60204700243e-12
# Sres_liq -327.691500882
# Sres_vap -1.24265273633e-09
# Res_S 327.69150088 J/mol 18.2050833822 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  33.0688821318 %, aceitável
# Hres_liq -54159.0350289
# Hres_vap -1.21315815015e-06
# Res_H 54159.0350276 J/mol 3008.83527931 kJ/kg
# Res_G 7.5054599442e-12
# Sres_liq -315.168699577
# Sres_vap -4.09503808564e-09
# Res_S 315.168699572 J/mol 17.5093721985 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 1.45519152284e-11
# DESVIO dH calc Dh exp:  32.240569672 %, aceitável
# Hres_liq -53821.9118603
# Hres_vap -3.78340307689e-06
# Res_H 53821.9118565 J/mol 2990.10621425 kJ/kg
# Res_G 3.9607562655e-12
# Sres_liq -303.448254155
# Sres_vap -1.240759879e-08
# Res_S 303.448254143 J/mol 16.8582363413 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  31.4212505835 %, aceitável
# Hres_liq -53488.4489984
# Hres_vap -1.09249937822e-05
# Res_H 53488.4489875 J/mol 2971.58049931 kJ/kg
# Res_G 4.46631966505e-12
# Sres_liq -292.456104183
# Sres_vap -3.4841853962e-08
# Res_S 292.456104148 J/mol 16.2475613416 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.45519152284e-11
# DESVIO dH calc Dh exp:  30.6103675995 %, aceitável
# Hres_liq -53158.4196424
# Hres_vap -2.94173459599e-05
# Res_H 53158.419613 J/mol 2953.24553406 kJ/kg
# Res_G 4.08020927429e-13
# Sres_liq -282.126964414
# Sres_vap -9.13155238121e-08
# Res_S 282.126964323 J/mol 15.6737202401 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  29.8073991887 %, aceitável
# Hres_liq -52831.6115441
# Hres_vap -7.43262505288e-05
# Res_H 52831.6114698 J/mol 2935.0895261 kJ/kg
# Res_G 9.44636979316e-12
# Sres_liq -272.403065504
# Sres_vap -2.24754418458e-07
# Res_S 272.403065279 J/mol 15.1335036266 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  29.0118557432 %, aceitável
# Hres_liq -52507.8254647
# Hres_vap -0.000177190880916
# Res_H 52507.8252875 J/mol 2917.10140486 kJ/kg
# Res_G 5.77285253292e-12
# Sres_liq -263.233105145
# Sres_vap -5.22366760224e-07
# Res_S 263.233104622 J/mol 14.6240613679 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  28.2232762073 %, aceitável
# Hres_liq -52186.8738169
# Hres_vap -0.000400533177676
# Res_H 52186.8734164 J/mol 2899.27074536 kJ/kg
# Res_G 8.65514338802e-13
# Sres_liq -254.571369733
# Sres_vap -1.15203394389e-06
# Res_S 254.571368581 J/mol 14.1428538101 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  27.4412250685 %, aceitável
# Hres_liq -51868.5794651
# Hres_vap -0.000862264175996
# Res_H 51868.5786029 J/mol 2881.58770016 kJ/kg
# Res_G 1.04794563869e-11
# Sres_liq -246.376995113
# Sres_vap -2.42140244387e-06
# Res_S 246.376992692 J/mol 13.6876107051 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 1.45519152284e-11
# DESVIO dH calc Dh exp:  26.6652896411 %, aceitável
# Hres_liq -51552.7746588
# Hres_vap -0.00177481490008
# Res_H 51552.7728839 J/mol 2864.042938 kJ/kg
# Res_G 7.42504365284e-13
# Sres_liq -238.613341359
# Sres_vap -4.86934878151e-06
# Res_S 238.61333649 J/mol 13.2562964716 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  25.8950775822 %, aceitável
# Hres_liq -51239.3000811
# Hres_vap -0.0035051587181
# Res_H 51239.296576 J/mol 2846.62758755 kJ/kg
# Res_G 7.77464507704e-12
# Sres_liq -231.247461605
# Sres_vap -9.4014168718e-06
# Res_S 231.247452203 J/mol 12.847080678 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.45519152284e-11
# DESVIO dH calc Dh exp:  25.1302145777 %, aceitável
# Hres_liq -50928.0039963
# Hres_vap -0.00666318382591
# Res_H 50927.9973331 J/mol 2829.33318517 kJ/kg
# Res_G 1.96760750054e-12
# Sres_liq -224.249648808
# Sres_vap -1.74822870715e-05
# Res_S 224.249631325 J/mol 12.4583128514 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  24.3703421457 %, aceitável
# Hres_liq -50618.7414803
# Hres_vap -0.012226950672
# Res_H 50618.7292533 J/mol 2812.15162518 kJ/kg
# Res_G 2.10958420871e-12
# Sres_liq -217.593047416
# Sres_vap -3.13990034848e-05
# Res_S 217.593016017 J/mol 12.0885008898 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  23.6151155047 %, aceitável
# Hres_liq -50311.3737244
# Hres_vap -0.0217140443241
# Res_H 50311.3520104 J/mol 2795.07511169 kJ/kg
# Res_G 2.90398781411e-12
# Sres_liq -211.253319332
# Sres_vap -5.46082681904e-05
# Res_S 211.253264724 J/mol 11.7362924847 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.45519152284e-11
# DESVIO dH calc Dh exp:  22.8642014572 %, aceitável
# Hres_liq -50005.7674014
# Hres_vap -0.0374083333661
# Res_H 50005.7299931 J/mol 2778.09611073 kJ/kg
# Res_G 4.86907215935e-12
# Sres_liq -205.2083555
# Sres_vap -9.21794010166e-05
# Res_S 205.208263321 J/mol 11.4004590734 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  22.1172762474 %, aceitável
# Hres_liq -49701.7940835
# Hres_vap -0.0626508322757
# Res_H 49701.7314327 J/mol 2761.20730182 kJ/kg
# Res_G 7.01463886976e-12
# Sres_liq -199.438025985
# Sres_vap -0.00015134147355
# Res_S 199.437874643 J/mol 11.0798819246 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  21.3740233543 %, aceitável
# Hres_liq -49399.3297072
# Hres_vap -0.102201951814
# Res_H 49399.2275052 J/mol 2744.40152807 kJ/kg
# Res_G 3.93816923516e-13
# Sres_liq -193.923962657
# Sres_vap -0.000242138720544
# Res_S 193.923720519 J/mol 10.7735400288 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  20.6341311928 %, aceitável
# Hres_liq -49098.2540757
# Hres_vap -0.16268019933
# Res_H 49098.0913955 J/mol 2727.67174419 kJ/kg
# Res_G 1.68777491982e-12
# Sres_liq -188.649369618
# Sres_vap -0.000378192823008
# Res_S 188.648991425 J/mol 10.4804995236 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  19.8972907014 %, aceitável
# Hres_liq -48798.4503949
# Hres_vap -0.253079433592
# Res_H 48798.1973155 J/mol 2711.01096197 kJ/kg
# Res_G 6.66211530387e-12
# Sres_liq -183.598857283
# Sres_vap -0.000577564402769
# Res_S 183.598279718 J/mol 10.1999044288 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  19.1631928091 %, aceitável
# Hres_liq -48499.8048365
# Hres_vap -0.385363233429
# Res_H 48499.4194733 J/mol 2694.41219296 kJ/kg
# Res_G 5.77293768345e-12
# Sres_liq -178.758296764
# Sres_vap -0.000863699521063
# Res_S 178.757433065 J/mol 9.93096850359 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  18.4315257827 %, aceitável
# Hres_liq -48202.2061246
# Hres_vap -0.575131031558
# Res_H 48201.6309936 J/mol 2677.86838853 kJ/kg
# Res_G 4.23877599687e-12
# Sres_liq -174.114691685
# Sres_vap -0.0012664406591
# Res_S 174.113425245 J/mol 9.67296806914 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  17.7019724678 %, aceitável
# Hres_liq -47905.5451411
# Hres_vap -0.84234665789
# Res_H 47904.7027944 J/mol 2661.37237747 kJ/kg
# Res_G 1.03350661362e-12
# Sres_liq -169.656065058
# Sres_vap -0.0018230760953
# Res_S 169.654241982 J/mol 9.42523566568 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  16.9742074482 %, aceitável
# Hres_liq -47609.7145475
# Hres_vap -1.21211612781
# Res_H 47608.5024314 J/mol 2644.91680174 kJ/kg
# Res_G 8.70747918214e-13
# Sres_liq -165.371359201
# Sres_vap -0.002579397268
# Res_S 165.368779804 J/mol 9.18715443356 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  16.2478941563 %, aceitável
# Hres_liq -47314.6084198
# Hres_vap -1.71549818547
# Res_H 47312.8929216 J/mol 2628.4940512 kJ/kg
# Res_G 1.08602016269e-12
# Sres_liq -161.250346992
# Sres_vap -0.00359073100555
# Res_S 161.246756261 J/mol 8.95815312559 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  15.5226819766 %, aceitável
# Hres_liq -47020.121893
# Hres_vap -2.39032853158
# Res_H 47017.7315645 J/mol 2612.09619803 kJ/kg
# Res_G 6.40809627583e-12
# Sres_liq -157.283553009
# Sres_vap -0.00492291267925
# Res_S 157.278630096 J/mol 8.73770167203 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  14.7982033863 %, aceitável
# Hres_liq -46726.1508153
# Hres_vap -3.28203703197
# Res_H 46722.8687782 J/mol 2595.71493212 kJ/kg
# Res_G 3.24229532112e-12
# Sres_liq -153.462183331
# Sres_vap -0.00665316749134
# Res_S 153.455530163 J/mol 8.52530723128 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  14.074071182 %, aceitável
# Hres_liq -46432.5914077
# Hres_vap -4.44443665026
# Res_H 46428.1469711 J/mol 2579.34149839 kJ/kg
# Res_G 4.95825602798e-12
# Sres_liq -149.778062919
# Sres_vap -0.0088708701976
# Res_S 149.769192049 J/mol 8.32051066938 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  13.3498758394 %, aceitável
# Hres_liq -46139.3399301
# Hres_vap -5.94046342481
# Res_H 46133.3994666 J/mol 2562.96663704 kJ/kg
# Res_G 1.15596421324e-12
# Sres_liq -146.223579698
# Sres_vap -0.0116781583781
# Res_S 146.211901539 J/mol 8.12288341886 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  12.6251830486 %, aceitável
# Hres_liq -45846.2923493
# Hres_vap -7.84284848306
# Res_H 45838.4495008 J/mol 2546.58052782 kJ/kg
# Res_G 2.11652917415e-12
# Sres_liq -142.791634522
# Sres_vap -0.0151903805812
# Res_S 142.776444141 J/mol 7.9320246745 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  11.8995314634 %, aceitável
# Hres_liq -45553.3440114
# Hres_vap -10.2347057406
# Res_H 45543.1093056 J/mol 2530.1727392 kJ/kg
# Res_G 4.65583127607e-12
# Sres_liq -139.475596361
# Sres_vap -0.0195363678499
# Res_S 139.456059994 J/mol 7.74755888853 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  11.1724306926 %, aceitável
# Hres_liq -45260.3893143
# Hres_vap -13.2100223926
# Res_H 45247.1792919 J/mol 2513.73218288 kJ/kg
# Res_G 5.57331958362e-12
# Sres_liq -136.269262108
# Sres_vap -0.0248585248262
# Res_S 136.244403583 J/mol 7.56913353241 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  10.4433595519 %, aceitável
# Hres_liq -44967.321381
# Hres_vap -16.8740433416
# Res_H 44950.4473376 J/mol 2497.24707431 kJ/kg
# Res_G 1.05693231944e-13
# Sres_liq -133.166820471
# Sres_vap -0.031312744329
# Res_S 133.135507727 J/mol 7.39641709594 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  9.71176458613 %, aceitável
# Hres_liq -44674.0317316
# Hres_vap -21.3435450737
# Res_H 44652.6881866 J/mol 2480.70489925 kJ/kg
# Res_G 2.85993451143e-12
# Sres_liq -130.16281951
# Sres_vap -0.0390681565714
# Res_S 130.123751353 J/mol 7.2290972974 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  8.97705885678 %, aceitável
# Hres_liq -44380.4099536
# Hres_vap -26.746998933
# Res_H 44353.6629547 J/mol 2464.09238637 kJ/kg
# Res_G 3.22764037719e-12
# Sres_liq -127.252137392
# Sres_vap -0.0483067306347
# Res_S 127.203830661 J/mol 7.06687948119 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  8.23862098239 %, aceitável
# Hres_liq -44086.3433679
# Hres_vap -33.2246280208
# Res_H 44053.1187398 J/mol 2447.39548555 kJ/kg
# Res_G 6.46238618174e-12
# Sres_liq -124.42995602
# Sres_vap -0.0592227511574
# Res_S 124.370733269 J/mol 6.9094851816 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  7.49579440706 %, aceitável
# Hres_liq -43791.7166895
# Hres_vap -40.9283658552
# Res_H 43750.7883237 J/mol 2430.59935132 kJ/kg
# Res_G 2.28794760915e-12
# Sres_liq -121.691737196
# Sres_vap -0.0720221972478
# Res_S 121.619714999 J/mol 6.75665083325 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  6.74788686436 %, aceitável
# Hres_liq -43496.4116821
# Hres_vap -50.0217283083
# Res_H 43446.3899538 J/mol 2413.68833077 kJ/kg
# Res_G 1.11946008019e-11
# Sres_liq -119.033201047
# Sres_vap -0.0869220533009
# Res_S 118.946278993 J/mol 6.60812661075 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -2.18278728426e-11
# DESVIO dH calc Dh exp:  5.99416999616 %, aceitável
# Hres_liq -43200.3068015
# Hres_vap -60.679613094
# Res_H 43139.6271884 J/mol 2396.64595491 kJ/kg
# Res_G 4.71800376545e-12
# Sres_liq -116.45030645
# Sres_vap -0.104149582725
# Res_S 116.346156867 J/mol 6.4636753815 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 7.27595761418e-12
# DESVIO dH calc Dh exp:  5.23387908029 %, aceitável
# Hres_liq -42903.2768288
# Hres_vap -73.088043148
# Res_H 42830.1887857 J/mol 2379.45493254 kJ/kg
# Res_G 1.06581410364e-14
# Sres_liq -113.939233229
# Sres_vap -0.123941595676
# Res_S 113.815291633 J/mol 6.32307175738 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  4.46621281619 %, aceitável
# Hres_liq -42605.1924878
# Hres_vap -87.4438716342
# Res_H 42517.7486162 J/mol 2362.09714534 kJ/kg
# Res_G 4.63629135083e-12
# Sres_liq -111.49636592
# Sres_vap -0.146543740915
# Res_S 111.349822179 J/mol 6.18610123218 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  3.69033311538 %, aceitável
# Hres_liq -42305.920045
# Hres_vap -103.95446706
# Res_H 42201.965578 J/mol 2344.55364322 kJ/kg
# Res_G 1.49924517245e-12
# Sres_liq -109.118278926
# Sres_vap -0.172209850118
# Res_S 108.946069076 J/mol 6.05255939312 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  2.90536484154 %, aceitável
# Hres_liq -42005.3208877
# Hres_vap -122.837397175
# Res_H 41882.4834905 J/mol 2326.80463836 kJ/kg
# Res_G 7.96518406787e-12
# Sres_liq -106.80172289
# Sres_vap -0.201201360538
# Res_S 106.600521529 J/mol 5.92225119607 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  2.11039544493 %, aceitável
# Hres_liq -41703.2510762
# Hres_vap -144.320130065
# Res_H 41558.9309461 J/mol 2308.829497 kJ/kg
# Res_G 3.04822833641e-12
# Sres_liq -104.54361215
# Sres_vap -0.233786839222
# Res_S 104.309825311 J/mol 5.79499029504 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  1.30447443534 %, aceitável
# Hres_liq -41399.5608654
# Hres_vap -168.639770236
# Res_H 41230.9210952 J/mol 2290.60672751 kJ/kg
# Res_G 9.34363697525e-12
# Sres_liq -102.341013148
# Sres_vap -0.270241629112
# Res_S 102.070771519 J/mol 5.67059841771 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.45519152284e-11
# DESVIO dH calc Dh exp:  0.486612638898 %, aceitável
# Hres_liq -41094.0941907
# Hres_vap -196.042846697
# Res_H 40898.051344 J/mol 2272.11396356 kJ/kg
# Res_G 7.50333128963e-12
# Sres_liq -100.191133667
# Sres_vap -0.31084763467
# Res_S 99.8802860322 J/mol 5.54890477957 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  -0.344218816146 %, aceitável
# Hres_liq -40786.6881109
# Hres_vap -226.785169096
# Res_H 40559.9029418 J/mol 2253.32794121 kJ/kg
# Res_G 6.21014351054e-12
# Sres_liq -98.0913128038
# Sres_vap -0.355893262213
# Res_S 97.7354195416 J/mol 5.42974553009 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  -1.18908983898 %, aceitável
# Hres_liq -40477.1722027
# Hres_vap -261.131767138
# Res_H 40216.0404355 J/mol 2234.22446864 kJ/kg
# Res_G 8.25650658953e-12
# Sres_liq -96.0390115803
# Sres_vap -0.405673528193
# Res_S 95.6333380521 J/mol 5.31296322512 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  -2.04911309648 %, aceitável
# Hres_liq -40165.3678975
# Hres_vap -299.356927754
# Res_H 39866.0109697 J/mol 2214.77838721 kJ/kg
# Res_G 2.38458142121e-11
# Sres_liq -94.0318041085
# Sres_vap -0.460490347255
# Res_S 93.5713137612 J/mol 5.19840632007 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -2.18278728426e-11
# DESVIO dH calc Dh exp:  -2.92544617081 %, aceitável
# Hres_liq -39851.0877525
# Hres_vap -341.74434399
# Res_H 39509.3434085 J/mol 2194.96352269 kJ/kg
# Res_G 6.12487838225e-12
# Sres_liq -92.0673692364
# Sres_vap -0.520653011185
# Res_S 91.5467162252 J/mol 5.08592867918 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  -3.81929421448 %, aceitável
# Hres_liq -39534.1346442
# Hres_vap -388.587389455
# Res_H 39145.5472547 J/mol 2174.75262526 kJ/kg
# Res_G 7.36122274247e-12
# Sres_liq -90.1434826024
# Sres_vap -0.586478869886
# Res_S 89.5570037325 J/mol 4.97538909625 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  -4.73191316723 %, aceitável
# Hres_liq -39214.3008734
# Hres_vap -440.189532416
# Res_H 38774.1113409 J/mol 2154.11729672 kJ/kg
# Res_G 2.17710294237e-11
# Sres_liq -88.2580090326
# Sres_vap -0.658294226386
# Res_S 87.5997148062 J/mol 4.86665082257 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -2.18278728426e-11
# DESVIO dH calc Dh exp:  -5.66461360648 %, aceitável
# Hres_liq -38891.3671666
# Hres_vap -496.864904408
# Res_H 38394.5022622 J/mol 2133.02790345 kJ/kg
# Res_G 8.75388650456e-12
# Sres_liq -86.4088952206
# Sres_vap -0.736435459633
# Res_S 85.672459761 J/mol 4.75958109783 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-12
# DESVIO dH calc Dh exp:  -6.61876531195 %, aceitável
# Hres_liq -38565.1015577
# Hres_vap -558.939039619
# Res_H 38006.162518 J/mol 2111.45347322 kJ/kg
# Res_G 2.14299689105e-11
# Sres_liq -84.5941626265
# Sres_vap -0.821250391558
# Res_S 83.772912235 J/mol 4.65405067972 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -2.91038304567e-11
# DESVIO dH calc Dh exp:  -7.59580263783 %, aceitável
# Hres_liq -38235.2581298
# Hres_vap -626.7498034
# Res_H 37608.5083264 J/mol 2089.36157369 kJ/kg
# Res_G 2.88196133624e-11
# Sres_liq -82.8119005371
# Sres_vap -0.913099918714
# Res_S 81.8988006184 J/mol 4.54993336769 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -2.91038304567e-11
# DESVIO dH calc Dh exp:  -8.59723080185 %, aceitável
# Hres_liq -37901.5755948
# Hres_vap -700.648531175
# Res_H 37200.9270636 J/mol 2066.7181702 kJ/kg
# Res_G 9.89075488178e-12
# Sres_liq -81.0602592244
# Sres_vap -1.01235993385
# Res_S 80.0478992906 J/mol 4.44710551614 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.45519152284e-11
# DESVIO dH calc Dh exp:  -9.62463322097 %, aceitável
# Hres_liq -37563.775682
# Hres_vap -781.001402955
# Res_H 36782.7742791 J/mol 2043.48745995 kJ/kg
# Res_G 1.80762071977e-11
# Sres_liq -79.3374431378
# Sres_vap -1.11942356926
# Res_S 78.2180195685 J/mol 4.34544553159 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.45519152284e-11
# DESVIO dH calc Dh exp:  -10.6796800499 %, aceitável
# Hres_liq -37221.5613035
# Hres_vap -868.191083778
# Res_H 36353.3702197 J/mol 2019.63167887 kJ/kg
# Res_G 6.15045792074e-11
# Sres_liq -77.6417040599
# Sres_vap -1.234703802
# Res_S 76.4070002579 J/mol 4.24483334766 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -6.54836185277e-11
# DESVIO dH calc Dh exp:  -11.7641381114 %, aceitável
# Hres_liq -36874.6144557
# Hres_vap -962.618667022
# Res_H 35911.9957886 J/mol 1995.11087715 kJ/kg
# Res_G 9.49285094975e-12
# Sres_liq -75.971334149
# Sres_vap -1.35863647128
# Res_S 74.6126976778 J/mol 4.14514987099 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? 0.0
# DESVIO dH calc Dh exp:  -12.8798824495 %, aceitável
# Hres_liq -36522.593809
# Hres_vap -1064.70596594
# Res_H 35457.8878431 J/mol 1969.88265795 kJ/kg
# Res_G 5.55928636459e-11
# Sres_liq -74.3246587795
# Sres_vap -1.49168377142
# Res_S 72.832975008 J/mol 4.04627638934 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -5.09317032993e-11
# DESVIO dH calc Dh exp:  -14.0289097888 %, aceitável
# Hres_liq -36165.1319255
# Hres_vap -1174.89820959
# Res_H 34990.233716 J/mol 1943.90187311 kJ/kg
# Res_G 1.5916157281e-11
# Sres_liq -72.7000290784
# Sres_vap -1.63433829982
# Res_S 71.0656907786 J/mol 3.94809393214 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.45519152284e-11
# DESVIO dH calc Dh exp:  -15.2133542529 %, aceitável
# Hres_liq -35801.8320321
# Hres_vap -1293.66721302
# Res_H 34508.1648191 J/mol 1917.12026773 kJ/kg
# Res_G 5.33191268914e-11
# Sres_liq -71.0958140388
# Sres_vap -1.78712776033
# Res_S 69.3086862785 J/mol 3.85048257103 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -5.09317032993e-11
# DESVIO dH calc Dh exp:  -16.4355057786 %, aceitável
# Hres_liq -35432.2642576
# Hres_vap -1421.51510944
# Res_H 34010.7491481 J/mol 1889.48606378 kJ/kg
# Res_G 3.52997631126e-11
# Sres_liq -69.510392063
# Sres_vap -1.95062044827
# Res_S 67.5597716147 J/mol 3.75332064526 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -3.63797880709e-11
# DESVIO dH calc Dh exp:  -17.697831777 %, aceitável
# Hres_liq -35055.9612214
# Hres_vap -1558.9787546
# Res_H 33496.9824668 J/mol 1860.94347038 kJ/kg
# Res_G 6.97468749422e-11
# Sres_liq -67.9421417604
# Sres_vap -2.12543167751
# Res_S 65.8167100828 J/mol 3.65648389349 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.27595761418e-11
# DESVIO dH calc Dh exp:  -19.0030027374 %, aceitável
# Hres_liq -34672.4128297
# Hres_vap -1706.63494379
# Res_H 32965.7778859 J/mol 1831.43210477 kJ/kg
# Res_G 3.47881723428e-11
# Sres_liq -66.3894317799
# Sres_vap -2.31223135379
# Res_S 64.0772004261 J/mol 3.55984446812 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -4.36557456851e-11
# DESVIO dH calc Dh exp:  -20.3539226602 %, aceitável
# Hres_liq -34281.0600978
# Hres_vap -1865.1066205
# Res_H 32415.9534773 J/mol 1800.88630429 kJ/kg
# Res_G 1.10730979941e-10
# Sres_liq -64.8506094011
# Sres_vap -2.511752956
# Res_S 62.3388564451 J/mol 3.46326980251 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.09139364213e-10
# DESVIO dH calc Dh exp:  -21.753765463 %, aceitável
# Hres_liq -33881.2877646
# Hres_vap -2035.070308
# Res_H 31846.2174566 J/mol 1769.23430314 kJ/kg
# Res_G 6.38920027995e-11
# Sres_liq -63.3239875332
# Sres_vap -2.72480426387
# Res_S 60.5991832693 J/mol 3.36662129274 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -6.91215973347e-11
# DESVIO dH calc Dh exp:  -23.2060188409 %, aceitável
# Hres_liq -33472.4153964
# Hres_vap -2217.26506463
# Res_H 31255.1503318 J/mol 1736.39724065 kJ/kg
# Res_G 4.50199877378e-11
# Sres_liq -61.8078296695
# Sres_vap -2.95228027333
# Res_S 58.8555493962 J/mol 3.26975274423 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -4.72937244922e-11
# DESVIO dH calc Dh exp:  -24.7145375318 %, aceitável
# Hres_liq -33053.6865827
# Hres_vap -2412.50335818
# Res_H 30641.1832245 J/mol 1702.28795692 kJ/kg
# Res_G 1.44041223393e-10
# Sres_liq -60.300332205
# Sres_vap -3.1951788806
# Res_S 57.1051533244 J/mol 3.17250851802 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.45519152284e-10
# DESVIO dH calc Dh exp:  -26.2836085753 %, aceitável
# Hres_liq -32624.2556954
# Hres_vap -2621.68438554
# Res_H 30002.5713098 J/mol 1666.80951721 kJ/kg
# Res_G 1.11072040454e-10
# Sres_liq -58.7996033338
# Sres_vap -3.45462010962
# Res_S 55.3449832241 J/mol 3.07472129023 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.09139364213e-10
# DESVIO dH calc Dh exp:  -27.9180320515 %, aceitável
# Hres_liq -32183.1715013
# Hres_vap -2845.81054625
# Res_H 29337.360955 J/mol 1629.85338639 kJ/kg
# Res_G 9.89075488178e-11
# Sres_liq -57.3036374715
# Sres_vap -3.73186992794
# Res_S 53.5717675435 J/mol 2.97620930797 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -9.82254277915e-11
# DESVIO dH calc Dh exp:  -29.6232220609 %, aceitável
# Hres_liq -31729.3566591
# Hres_vap -3086.00803793
# Res_H 28643.3486212 J/mol 1591.29714562 kJ/kg
# Res_G 9.97033566819e-11
# Sres_liq -55.8102837648
# Sres_vap -4.02837008166
# Res_S 51.7819136831 J/mol 2.8767729824 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -9.45874489844e-11
# DESVIO dH calc Dh exp:  -31.4053345527 %, aceitável
# Hres_liq -31261.5817546
# Hres_vap -3343.55291756
# Res_H 27918.028837 J/mol 1551.00160206 kJ/kg
# Res_G 1.04478203866e-10
# Sres_liq -54.3172066907
# Sres_vap -4.34577593913
# Res_S 49.9714307515 J/mol 2.77619059731 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.05501385406e-10
# DESVIO dH calc Dh exp:  -33.2714313295 %, aceitável
# Hres_liq -30778.4319753
# Hres_vap -3619.90452641
# Res_H 27158.5274489 J/mol 1508.80708049 kJ/kg
# Res_G 1.23691279441e-10
# Sres_liq -52.8218359224
# Sres_vap -4.68600515928
# Res_S 48.1358307632 J/mol 2.67421282018 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.23691279441e-10
# DESVIO dH calc Dh exp:  -35.2296936679 %, aceitável
# Hres_liq -30278.2636901
# Hres_vap -3916.74901291
# Res_H 26361.5146772 J/mol 1464.52859318 kJ/kg
# Res_G 1.75987224793e-10
# Sres_liq -51.321301392
# Sres_vap -5.05130124947
# Res_S 46.2700001426 J/mol 2.57055556348 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.78260961547e-10
# DESVIO dH calc Dh exp:  -37.2897053436 %, aceitável
# Hres_liq -29759.1469053
# Hres_vap -4236.05698015
# Res_H 25523.0899251 J/mol 1417.94944029 kJ/kg
# Res_G 2.69210431725e-10
# Sres_liq -49.8123475429
# Sres_vap -5.44431801228
# Res_S 44.3680295307 J/mol 2.46489052948 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -2.65572452918e-10
# DESVIO dH calc Dh exp:  -39.4628349469 %, aceitável
# Hres_liq -29218.7875156
# Hres_vap -4580.16133903
# Res_H 24638.6261766 J/mol 1368.81256537 kJ/kg
# Res_G 1.70530256582e-10
# Sres_liq -48.2912176888
# Sres_vap -5.86823396099
# Res_S 42.4229837278 J/mol 2.35683242932 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.7462298274e-10
# DESVIO dH calc Dh exp:  -41.7627639262 %, aceitável
# Hres_liq -28654.4198996
# Hres_vap -4951.86481755
# Res_H 23702.555082 J/mol 1316.80861567 kJ/kg
# Res_G 3.56067175744e-10
# Sres_liq -46.7534943312
# Sres_vap -6.32691084528
# Res_S 40.4265834859 J/mol 2.24592130477 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -3.60159901902e-10
# DESVIO dH calc Dh exp:  -44.2062349581 %, aceitável
# Hres_liq -28062.6546779
# Hres_vap -5354.59230587
# Res_H 22708.0623721 J/mol 1261.55902067 kJ/kg
# Res_G 3.50382833858e-10
# Sres_liq -45.1938726665
# Sres_vap -6.82511905319
# Res_S 38.3687536133 J/mol 2.13159742296 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -3.49245965481e-10
# DESVIO dH calc Dh exp:  -46.8141451685 %, aceitável
# Hres_liq -27439.2562948
# Hres_vap -5792.61337841
# Res_H 21646.6429164 J/mol 1202.59127313 kJ/kg
# Res_G 1.95996108232e-10
# Sres_liq -43.6058291858
# Sres_vap -7.36886798039
# Res_S 36.2369612054 J/mol 2.01316451141 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -1.96450855583e-10
# DESVIO dH calc Dh exp:  -49.6132017869 %, aceitável
# Hres_liq -26778.8061429
# Hres_vap -6271.37927022
# Res_H 20507.4268727 J/mol 1139.30149293 kJ/kg
# Res_G 3.40833139489e-10
# Sres_liq -41.9811186573
# Sres_vap -7.96590807397
# Res_S 34.0152105834 J/mol 1.8897339213 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -3.3833202906e-10
# DESVIO dH calc Dh exp:  -52.6385418254 %, aceitável
# Hres_liq -26074.1695089
# Hres_vap -6798.05603183
# Res_H 19276.1134771 J/mol 1070.89519317 kJ/kg
# Res_G 4.0267877921e-10
# Sres_liq -40.3089760804
# Sres_vap -8.6265279583
# Res_S 31.6824481221 J/mol 1.76013600679 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -4.03815647587e-10
# DESVIO dH calc Dh exp:  -55.9381086478 %, aceitável
# Hres_liq -25315.6049905
# Hres_vap -7382.41521014
# Res_H 17933.1897803 J/mol 996.28832113 kJ/kg
# Res_G 3.98586053052e-10
# Sres_liq -38.5747793934
# Sres_vap -9.36489085627
# Res_S 29.2098885371 J/mol 1.6227715854 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -3.96539689973e-10
# DESVIO dH calc Dh exp:  -59.5804896013 %, aceitável
# Hres_liq -24489.1695869
# Hres_vap -8038.42885464
# Res_H 16450.7407323 J/mol 913.930040681 kJ/kg
# Res_G 4.08363121096e-10
# Sres_liq -36.7576467774
# Sres_vap -10.201436462
# Res_S 26.5562103153 J/mol 1.47534501752 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -4.07453626394e-10
# DESVIO dH calc Dh exp:  -63.6703084956 %, aceitável
# Hres_liq -23573.5863763
# Hres_vap -8787.40193399
# Res_H 14786.1844423 J/mol 821.454691239 kJ/kg
# Res_G 3.74029696104e-10
# Sres_liq -34.8257015507
# Sres_vap -11.1676152666
# Res_S 23.6580862841 J/mol 1.3143381269 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -3.7471181713e-10
# DESVIO dH calc Dh exp:  -68.3826372076 %, aceitável
# Hres_liq -22533.2418002
# Hres_vap -9664.9751437
# Res_H 12868.2666565 J/mol 714.903703138 kJ/kg
# Res_G 5.60476109968e-10
# Sres_liq -32.7254476706
# Sres_vap -12.3165123182
# Res_S 20.4089353524 J/mol 1.1338297418 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -5.60248736292e-10
# DESVIO dH calc Dh exp:  -74.0568357885 %, aceitável
# Hres_liq -21299.0892467
# Hres_vap -10740.2214127
# Res_H 10558.8678341 J/mol 586.603768559 kJ/kg
# Res_G 6.12999428995e-10
# Sres_liq -30.3526852639
# Sres_vap -13.7519309912
# Res_S 16.6007542727 J/mol 0.922264126262 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -6.11180439591e-10
# DESVIO dH calc Dh exp:  -81.5638006813 %, aceitável
# Hres_liq -19693.914082
# Hres_vap -12190.3809593
# Res_H 7503.53312269 J/mol 416.862951261 kJ/kg
# Res_G 7.39873939892e-10
# Sres_liq -27.4382073023
# Sres_vap -15.7426956477
# Res_S 11.6955116545 J/mol 0.649750647474 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -7.39419192541e-10
# DESVIO dH calc Dh exp:  -99.7485366921 %, aceitável
# Hres_liq -15907.9593235
# Hres_vap -15805.6137572
# Res_H 102.345566296 J/mol 5.6858647942 kJ/kg
# Res_G 3.81976406061e-07
# Sres_liq -21.1991441768
# Sres_vap -21.0409838203
# Res_S 0.158160356479 J/mol 0.00878668647106 kJ/kg
# PROVA REAL: DELTAH-TDELTAS=0?? -3.81976661856e-07
